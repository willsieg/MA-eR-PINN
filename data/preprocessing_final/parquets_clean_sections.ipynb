# %%
#%reset -f 
import sys, os, pickle, random
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
import matplotlib.pyplot as plt

from datetime import datetime
from pathlib import Path
from scipy.signal import savgol_filter
from scipy.stats import zscore, median_abs_deviation
from itertools import groupby

from IPython.core.magic import register_cell_magic
@register_cell_magic
def skip(line, cell): return  # cells can be skipped by using '%%skip' in the first line

# %%
# -----------> SET DATA FOLDER LOCATION HERE:
#DATA_PATH = Path('/home', 'sieglew', 'MA-Data')
DATA_PATH = Path(r'C:\Users\SIEGLEW\OneDrive - Daimler Truck\MA\Code\MA-Data')

# FILE SOURCES ---------------------------------------------------------------
original_trips_folder = Path(DATA_PATH, "processed") # original Trip parquet files

# OUTPUT LOCATIONS ---------------------------------------------------------------
trips_processed_final = Path(DATA_PATH, "new_folder") # Save new files here
trips_processed_cleaned = Path(DATA_PATH, "new_folder_2") # Save new files here

# %%
# GET DIRECTORY CONTENS:
def get_files(folder, ext, full = False): return [file if full else file.name for file in folder.glob(f'*{ext}')]
trips = get_files(trips_processed_final, ".parquet", full = False)
original_trips = get_files(original_trips_folder, ".parquet", full = False)
len(trips)
# Out:
# 358

# %%
# get list of signals
df = pd.read_parquet(Path(trips_processed_final, trips[13]), engine='fastparquet')
all_columns = df.columns
assert len(all_columns) == 114

# %%
# SUMMARY OF ANALYSIS: 
#############################################################################################################################################
# SIGNALS  ###################################################################################################
# these signals always have more than 90% nans and will be removed from all trips:
sparse_signals = {'odometer','signal_date','vehicle_id', 'diff',
                  'chrgcoupproxydet_stat','hv_batmaxdischrgpwrlim_cval', 'hv_ptc2_pwr_cval',
                  'inv1_curr_cval_api1','inv1_pwr_cval_api1','inv1_pwr_cval_api3','inv1_spd_cval_api1','inv2_curr_cval_api2','inv2_pwr_cval_api2', 'inv2_spd_cval_api2'}

# these signals are either all-nans in a significant amount of trips or are too redundant/insignificant and will thus be removed from all trips:
remove_signals = {"minmoduletempindex_bms01", "maxmoduletempindex_bms01", "brc_stat_brc2", "maxpwr_contendrnbrkresist2","currtmp_brkresist2int_cval", "currpwr_contendrnbrkresist2",
                  "plugchrg_stat", "hv_chrgpwr_ecpc_cval", "chargestate", "dsrdpwr_contendrn_cval", "dsrdpwr_contendrn2_cval","maproadgrad_cval", "airtempoutsd_cval_sca", 
                  "meanmoduletemperature_bms01", "linkvoltage_bms05", "lv_conv_voltdmd_e2e_dcl1", "lv_convmaxcurr_cval_dcl1", "lv_convcurr_cval_dcl1","lv_conv_dc_momvolt_cval_dcl1", 
                  "hv_batlinkvoltage_sc01", "hv_dclink_volt_cval_brc", "hv_dclink_volt_cval_brc2", "oiltemp_ra_cval","hv_bat_intres_cval_bms1", "stringvoltage_bms01", 
                  "currtmp_brkresist1int_cval", "maxpwr_contendrnbrkresist_cval", "hv_bat_dc_volt_cval_bms1", "pt4_dcb_temp2_st3", "pt4_dcb_temp1_st3", "maxbrickvoltage_bms01",
                  'cc_actv_stat', 'cc_setspd_cval', 'pt4_dcb_hvdc_power_max_st3', 'hv_bathighcelltemp_cval_bms1', 'hv_batlowcelltemp_cval_bms1', 'hv_batmomavlchrgen_cval_bms1', 
                  'signal_ts', 'hv_bat_soh_cval_bms1', 'grocmbvehweight_cval'}

# these signals are either identical or too correlated with one of the other signals and will be removed from all trips:
redundant_signals = {'hirestotalvehdist_cval_cpc', 'ambtemp_cval_pt', 'grshift_stat_pt', 'currgr_stat_edcu', 'edrvspd_cval', 'hv_bat_dc_maxvoltlim_cval',
                     'hv_bat_dc_minvoltlim_cval', 'ignsw_stat_sca'}
                     
drop_signals = list(sparse_signals | remove_signals | redundant_signals)

# interrelated signal pairs can be combined (mean with nans ignored) to only introduce one variable:
pair_signals = [('actualdcvoltage_pti1', 'actualdcvoltage_pti2'), # only the first variable of each pair will be kept
                ('actualspeed_pti1', 'actualspeed_pti2'), 
                ('actualtorque_pti1','actualtorque_pti2'),
                ('motortemperature_pti1','motortemperature_pti2'),
                ('powerstagetemperature_pti1', 'powerstagetemperature_pti2'),
                ('rmsmotorcurrent_pti1','rmsmotorcurrent_pti2'),
                ('brktempra_cval', 'brktempfa_cval'),
                ('roadgrad_cval_pt','bs_roadincln_cval')]

# these signals should be explicitly considered for outlier removal to clean and improve data quality
signal_remove_outliers = ["roadgrad_cval_pt","hirestotalvehdist_cval_icuc","vehspd_cval_cpc", 
                        "hv_batmomavldischrgen_cval_1", "hv_bat_soc_cval_bms1", "airtempinsd_cval_hvac", "airtempoutsd_cval_cpc","hv_bathighcelltemp_cval_bms1",
                        "hv_batlowcelltemp_cval_bms1", "hv_dclink_volt_cval_dcl1", "actualdcvoltage_pti1", "hv_bat_dc_momvolt_cval_bms1","hv_batmaxchrgpwrlim_cval_1", 
                        "hv_batmaxdischrgpwrlim_cval_1"]

# optional signals
# could be kept and filled with zeros/ones instead, to retain the ePTO feature if available in the truck
optional_or_zero = ['epto_pwr_cval', 'currpwr_contendrnbrkresist_cval', 'elcomp_pwrcons_cval'] # --> fill with: "0" if not available
optional_or_one = ['brc_stat_brc1'] #--> fill with "1" if not available

# FILES  ###################################################################################################
# these trips do not contain valid trips or are too short or are sorted out for other reasons
invalid_original_trips = ['v_id983V101_trip30.parquet', 'v_id983V101_trip70.parquet', 'v_id983V101_trip8.parquet', 'v_id983V101_trip94_2.parquet', 'v_id983V10_trip19.parquet', 
                           'v_id983V10_trip22.parquet', 'v_id983V10_trip32.parquet', 'v_id983V10_trip36.parquet', 'v_id983V13_trip199.parquet', 'v_id983V14_trip9.parquet', 
                           'v_id983V15_trip70.parquet', 'v_id983V16_trip1.parquet', 'v_id983V16_trip178.parquet', 'v_id983V16_trip185.parquet', 'v_id983V16_trip197.parquet', 
                           'v_id983V16_trip2.parquet', 'v_id983V17_trip132.parquet', 'v_id983V18_trip198.parquet', 'v_id983V18_trip2.parquet', 'v_id983V18_trip218.parquet', 
                           'v_id983V18_trip6.parquet', 'v_id983V19_trip111.parquet', 'v_id983V19_trip113.parquet', 'v_id983V19_trip87.parquet', 'v_id983V19_trip99.parquet', 
                           'v_id983V1_trip100.parquet', 'v_id983V1_trip109.parquet', 'v_id983V1_trip116.parquet', 'v_id983V1_trip117.parquet', 'v_id983V1_trip118.parquet', 
                           'v_id983V1_trip13.parquet', 'v_id983V1_trip132.parquet', 'v_id983V1_trip142.parquet', 'v_id983V1_trip162.parquet', 'v_id983V1_trip163.parquet', 
                           'v_id983V1_trip26.parquet', 'v_id983V1_trip31.parquet', 'v_id983V1_trip40.parquet', 'v_id983V1_trip41.parquet', 'v_id983V1_trip43.parquet', 
                           'v_id983V1_trip44.parquet', 'v_id983V1_trip46.parquet', 'v_id983V1_trip54.parquet', 'v_id983V1_trip6.parquet', 'v_id983V2_trip60.parquet', 
                           'v_id983V4_trip139.parquet', 'v_id983V4_trip36.parquet', 'v_id983V4_trip58.parquet', 'v_id983V1_trip118.parquet', 'v_id983V1_trip132.parquet', 
                           'v_id983V14_trip9.parquet', 'v_id983V10_trip19.parquet', 'v_id983V17_trip132.parquet', 'v_id983V1_trip163.parquet', 'v_id983V1_trip132.parquet', 
                           'v_id983V10_trip19.parquet', 'v_id983V1_trip163.parquet', 'v_id983V1_trip132.parquet', 'v_id983V1_trip163.parquet', 'v_id983V19_trip87.parquet', 
                           'v_id983V1_trip163.parquet']

# %%
trips = [_ for _ in trips if _ not in invalid_original_trips]
print('Keep no. trips: ', len(trips))

keep_signals = [col for col in all_columns if col not in drop_signals + [b for _, b in pair_signals]]
print('Keep no. signals: ', len(keep_signals))
# Out:
# Keep no. trips:  358
# Keep no. signals:  44

# %%
# UTILS
####################################################################################################
def expand_indices(r_list, ws, offset, max_val):
    r_set = set(r_list).copy()
    for i in range(-ws,ws+1):
        r_set = r_set | set([x+i for x in r_list])
    r_set = [x+offset for x in list(r_set)]
    drops = [x for x in list(r_set) if (x>=0 and x<max_val)]
    return sorted(drops)

####################################################################################################   
def smooth_filter(X, ws, remove_outliers = True, smooth = True):

    def custom_filter(X,ws, remove_outliers, thresh = 8):
        X_filtered = X.copy()
        X_noise  = abs(zscore(X.ffill().bfill() - savgol_filter(X.ffill().bfill(), ws,1, mode='nearest'), nan_policy='omit'))
        if remove_outliers:
            cr = X.std() - median_abs_deviation(X, nan_policy='omit')
            thresh_new = max(abs(X.std() / cr), thresh) if cr != 0 else max(abs(X.std()), thresh)
            peaks = expand_indices(list(np.where((X_noise > thresh_new))[0]), int(ws), 0, len(X))
            X_filtered[peaks] = np.nan
            X_filtered[X_noise.isna()] = np.nan
        else:
            thresh_new = None

        if X_filtered.nunique() < 2:
            X_filtered.fillna(X_filtered.mean(), inplace=True)
        else:
            X_filtered.ffill(inplace=True)
            X_filtered.bfill(inplace=True)  

        return X_filtered, X_noise, thresh_new

    X_filtered, X_noise, thresh = custom_filter(X, ws, remove_outliers = remove_outliers)
    
    if (X - X_filtered).std() > 10:
        X_filtered, X_noise, thresh = custom_filter(X_filtered, ws, remove_outliers = remove_outliers)

    if smooth: X_filtered = savgol_filter(X_filtered, ws/2,1, mode='nearest')
    return X_filtered, X_noise, thresh

####################################################################################################
def get_slices(c_state, min_length=60, exp=lambda val: val == 0):
        slices = []
        start = None
        for i, val in enumerate(c_state):
            condition = exp(val)
            if condition and start is None:
                    start = i
            elif not condition and start is not None:
                    if (i - start) >= min_length:
                        slices.append(slice(start, i))
                    start = None
        if start is not None and (len(c_state) - start) >= min_length:
            slices.append(slice(start, len(c_state)))
        return slices

####################################################################################################
def intersect_slices(slices_A, slices_B):
    intersection_slices = []
    for v_slice in slices_A:
        for c_slice in slices_B:
            start = max(v_slice.start, c_slice.start)
            stop = min(v_slice.stop, c_slice.stop)
            if start < stop:
                intersection_slices.append(slice(start, stop))
    return intersection_slices

####################################################################################################
def split_dataframe_by_slices(df, slices):
    return [df.iloc[s] for s in slices]

####################################################################################################
idx_dict = {}
def save_dataframes_to_parquet(dataframes, base_path, idx_dict, veh_id):
    if f"{veh_id}" not in idx_dict: idx_dict[f"{veh_id}"] = 0
    start_idx = idx_dict[f"{veh_id}"]+1
    new_files = []
    for i, df in enumerate(dataframes):
        filename = f"V{veh_id}_T{i+start_idx}.parquet"
        new_files.append(filename)
        df.to_parquet(Path(base_path, filename), engine='fastparquet')
    idx_dict[f"{veh_id}"] = start_idx + i
    return new_files, idx_dict

####################################################################################################
def find_nan_sections(series):
    nan_sections = []
    start_idx = None

    for idx, value in series.isna().items():
        if value and start_idx is None:
            start_idx = idx
        elif not value and start_idx is not None:
            if idx > start_idx + 2:
                nan_sections.append(start_idx)
            start_idx = None

    if start_idx is not None:
        nan_sections.append(start_idx)

    # Remove neighboring numbers
    nan_sections = [nan_sections[i] for i in range(len(nan_sections)) if i == 0 or nan_sections[i] != nan_sections[i-1] + 1]

    return nan_sections

# %%
from collections import Counter
vehicle_counts = Counter()

for trip in trips:
    vehicle_id = trip[1:4].strip("_TV."); file_code = trip[:9].strip(".parquet")
    #print(f"\tVehicle ID: {vehicle_id}, File Code: {file_code}")
    vehicle_counts[vehicle_id] += 1
vehicle_counts
# Out:
# Counter({'101': 358})

# %%
# PREPROCESSING #########################################################
save = True
#########################################################################
# loop through every file:
v_idx = {}
cut_list = []
nan_files = []
discard_files = []
for n, f in enumerate(trips):
    #if n>0: break
    # get file info
    vehicle_id = f[1:4].strip("_TV."); #file_code = f[:9].strip(".parquet")
    if vehicle_id not in v_idx: v_idx[vehicle_id] = 0
    v_idx[vehicle_id] += 1
    # new file numbering
    new_name = f"V{vehicle_id}_T{v_idx[vehicle_id]}"
    print(f"{n+1}/{len(trips)}, Reading File: {f}, New File Name: {new_name}")

    # read to dataframe
    keep_columns = [col for col in all_columns if col not in drop_signals]
    df = pd.read_parquet(Path(trips_processed_final, f), columns = keep_columns, engine='fastparquet')
    # drop certain signals according to previous analysis (not necessary if keep_columns is used)
    # df.drop(columns = drop_signals, inplace=True)

    # concatenate signal pairs
    for pair in pair_signals:
        df[pair[0]] = df[[pair[0],pair[1]]].mean(axis=1, skipna=True)
        df.drop(columns=[pair[1]], inplace=True)

    # correct timestamp if necessary:
    if max(df.signal_time).year < 2000: df.signal_time = pd.to_datetime(df.signal_ts * (10**3))
    if not ((df['signal_time'].dt.year >= 2021) & (df['signal_time'].dt.year <= 2024)).all(): 
        raise ValueError("signal_time values are not all between 2021 and 2024")
    df['signal_time'] = df['signal_time'].dt.round('1s')

    #####################################################################################
    # df column structure: [i,      0,              1,                  2, 3, 4,                    5                               -2, -1          ]
    #                      [row,    Date/Time,      Dist. from start,   Altitude + GPS,             features 1,2,...,n              targets,        ]
    #                      [index,  'signal_time',  'hirestotal...',    'altitude','lat','long',    signal_a, signal_b, c, ...      'bat_en','SOC'  ]
    #####################################################################################
    #  --> move signal_time as first column, then sort remaining columns alphabetically
    df.reset_index(drop=True, inplace=True)  # --> reset index to start from 0
    #df.sort_index(axis=1, inplace=True)
    # Reorder columns based on structure above:
    start_cols = ['signal_time','hirestotalvehdist_cval_icuc','altitude_cval_ippc', 'latitude_cval_ippc','longitude_cval_ippc']
    target_cols = ['hv_batmomavldischrgen_cval_1', 'hv_bat_soc_cval_bms1']
    feature_cols = sorted([col for col in df.columns if col not in start_cols + target_cols])
    columns_order = start_cols + feature_cols + target_cols
    df = df[columns_order]

    #####################################
    # remove distance offset, so each sequence starts at 0 km
    dist_offset = abs(df["hirestotalvehdist_cval_icuc"].iloc[df["hirestotalvehdist_cval_icuc"].first_valid_index()])
    df["hirestotalvehdist_cval_icuc"] -= dist_offset

    #####################################
    signal_only_nans = [sig for sig in list(df.columns[np.array(df.isnull().all())])]
    signal_with_nans = [sig for sig in list(df.columns[np.array(df.isnull().any())])]
    constants = {}

    # fill optional signals apporpriately
    for sig in signal_only_nans:
        if sig in optional_or_zero: df[sig] = 0.0
        elif sig in optional_or_one: df[sig] = 1.0

    for sig in df.columns:
        if True:
            # extract constant values if available:
            if len({x for x in df[sig] if x==x}) == 1:      # number of distinct non-NaN-values
                constants[sig] = df[sig].iloc[df[sig].first_valid_index()] 
            # Filtering, smoothing and outlier removal:
        if sig in signal_remove_outliers:   # DO NOT USE REMOVE OUTLIER FUNCTION
                df[sig], _, _ = smooth_filter(df[sig], 60, remove_outliers = True, smooth = False)

    #####################################
    # clip value limits for specified value ranges: --> replace with nans instead 
    #clip after filtering!!
    value_ranges = {'vehspd_cval_cpc': (0, 110),    # set ranges
                    'hv_batmomavldischrgen_cval_1': (2, 440),
                    'altitude_cval_ippc': (-20, 2800),
                    'roadgrad_cval_pt': (-20, 20),
                    'longitude_cval_ippc': (-5, 35),
                    'latitude_cval_ippc': (35, 68),
                    'vehweight_cval_pt': (7, 44),
                    'airtempoutsd_cval_cpc': (-30, 48),
                    'actualtorque_pti1': (-100, 100),
                    'elcomp_pwrcons_cval': (0, 14),
                    'hv_bat_soc_cval_bms1': (4.9, 100),
                    'hv_batavcelltemp_cval_bms1': (-10, 48),
                    'epto_pwr_cval': (0, 20), 
                    'currpwr_contendrnbrkresist_cval': (0, 90),
                    'brc_stat_brc1': [1.0, 2.0, 3.0], # set values
                    'selgr_rq_pt': [0.0, 1.0, 2.0]} # set values

    for signal, value_range in value_ranges.items():
        if isinstance(value_range, tuple):
            if (df[signal] < value_range[0]).any() or (df[signal] > value_range[1]).any():
                df.loc[(df[signal] < value_range[0]) | (df[signal] > value_range[1]), signal] = np.nan
                print(f"\tSignal {signal} clipped to range {value_range}")
        elif isinstance(value_range, list): df[signal] = df[signal].apply(lambda x: x if any(abs(x - y) <= 0.1 for y in value_range) else np.nan)


    # check if after clipping any column is all nans. if so, discard the file
    if df.isnull().all().any():
        all_nan_columns = df.columns[df.isnull().all()].tolist()
        print(f'Warning: All NaN values in {f}, columns: {all_nan_columns}\n{"-"*120}\n')
        discard_files.append(f)
        continue


    #####################################
    # cut first section, if altitude jump is still detected after preprocessing:
    alt_diff = pd.DataFrame(abs(np.diff(df["altitude_cval_ippc"])))
    lat_diff = pd.DataFrame(abs(np.diff(df["latitude_cval_ippc"])))

    exceed_indices = alt_diff[alt_diff[0] > 100].index.union(lat_diff[lat_diff[0] > 10].index) # sudden altitude jumps of more than 50m or latitude jumps of more than 10 degrees
    exceed_indices = sorted(set(exceed_indices))  # remove duplicates and sort


    if exceed_indices:
        print(alt_diff[0].max())
        print(lat_diff[0].max())
        print(f"\t exceed indices: {exceed_indices}")
        print(f"\tAltitude jump of {alt_diff[0].iloc[exceed_indices[-1]]} detected at index {exceed_indices[-1]}")
        l = len(df) # old length
        if len(df.loc[0:exceed_indices[0]-3]) > len(df.loc[exceed_indices[-1]+3:]):
            df = df.loc[0:exceed_indices[0]-3]  # cut last section
        else:
            df = df.loc[exceed_indices[-1]+3:]  # cut first section
        df.reset_index(drop=True, inplace=True) # reset index
        print(f"\t --> cut: {((l-len(df))/l*100):.2f} %")    # percentage of cut
        if ((l-len(df))/l*100) > 10: cut_list.append((f, ((l-len(df))/l*100)))
        if ((l-len(df))/l*100) > 50: 
            discard_files.append(f)
            print(f"\t --> discarded due to cut:")
            continue

    #####################################
    # check again for nans and fill only columns with nans:
    columns_with_nans = [sig for sig in df.columns[df.isna().any()].tolist()]
    if columns_with_nans: 
        df[columns_with_nans] = df[columns_with_nans].ffill().bfill()
    # check if there are still any nans:
    if df[columns_with_nans].isna().any().any(): 
        columns_with_nans = [sig for sig in df.columns[df.isna().any()].tolist()]
        if df[columns_with_nans].isnull().all().any():
            print(f'Error: All values are NaN in columns: {columns_with_nans} for file {f}\n{"-"*120}\n')
            discard_files.append(f)
            continue
        else:
            print(f'Warning: Still some NaN values in {f}, columns_with_nans: {columns_with_nans}\n{"-"*120}\n')
            print(f"number of nans: {df[columns_with_nans].isna().sum()}")
            nan_files.append(f)

    #####################################
    # Convert each column to datatype "float64", except for "signal_time"
    for col in df.columns: 
        if col not in ['signal_time']: df[col] = df[col].astype('float64')

    ############################################################################################
    # Save new dataframes
    if save:
        df.to_parquet(f'{trips_processed_cleaned}/{new_name}.parquet')
        print(f'\t --> "{new_name}.parquet" saved.\n{"-"*60}\n')
# Out:
# 1/358, Reading File: V101_T1.parquet, New File Name: V101_T1
# 	 --> "V101_T1.parquet" saved.
# ------------------------------------------------------------
#
# 2/358, Reading File: V101_T10.parquet, New File Name: V101_T2
# 	 --> "V101_T2.parquet" saved.
# ------------------------------------------------------------
#
# 3/358, Reading File: V101_T100.parquet, New File Name: V101_T3
# 	 --> "V101_T3.parquet" saved.
# ------------------------------------------------------------
#
# 4/358, Reading File: V101_T101.parquet, New File Name: V101_T4
# 	 --> "V101_T4.parquet" saved.
# ------------------------------------------------------------
#
# 5/358, Reading File: V101_T102.parquet, New File Name: V101_T5
# 	 --> "V101_T5.parquet" saved.
# ------------------------------------------------------------
#
# 6/358, Reading File: V101_T103.parquet, New File Name: V101_T6
# 	 --> "V101_T6.parquet" saved.
# ------------------------------------------------------------
#
# 7/358, Reading File: V101_T104.parquet, New File Name: V101_T7
# 	 --> "V101_T7.parquet" saved.
# ------------------------------------------------------------
#
# 8/358, Reading File: V101_T105.parquet, New File Name: V101_T8
# 	 --> "V101_T8.parquet" saved.
# ------------------------------------------------------------
#
# 9/358, Reading File: V101_T106.parquet, New File Name: V101_T9
# 	 --> "V101_T9.parquet" saved.
# ------------------------------------------------------------
#
# 10/358, Reading File: V101_T107.parquet, New File Name: V101_T10
# 	 --> "V101_T10.parquet" saved.
# ------------------------------------------------------------
#
# 11/358, Reading File: V101_T108.parquet, New File Name: V101_T11
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T11.parquet" saved.
# ------------------------------------------------------------
#
# 12/358, Reading File: V101_T109.parquet, New File Name: V101_T12
# 	 --> "V101_T12.parquet" saved.
# ------------------------------------------------------------
#
# 13/358, Reading File: V101_T11.parquet, New File Name: V101_T13
# 	 --> "V101_T13.parquet" saved.
# ------------------------------------------------------------
#
# 14/358, Reading File: V101_T110.parquet, New File Name: V101_T14
# 	 --> "V101_T14.parquet" saved.
# ------------------------------------------------------------
#
# 15/358, Reading File: V101_T111.parquet, New File Name: V101_T15
# 	 --> "V101_T15.parquet" saved.
# ------------------------------------------------------------
#
# 16/358, Reading File: V101_T112.parquet, New File Name: V101_T16
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 112.47916666666666
# 0.00020100000002543084
# 	 exceed indices: [0]
# 	Altitude jump of 112.47916666666666 detected at index 0
# 	 --> cut: 0.34 %
# 	 --> "V101_T16.parquet" saved.
# ------------------------------------------------------------
#
# 17/358, Reading File: V101_T113.parquet, New File Name: V101_T17
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T17.parquet" saved.
# ------------------------------------------------------------
#
# 18/358, Reading File: V101_T114.parquet, New File Name: V101_T18
# 	 --> "V101_T18.parquet" saved.
# ------------------------------------------------------------
#
# 19/358, Reading File: V101_T115.parquet, New File Name: V101_T19
# 	 --> "V101_T19.parquet" saved.
# ------------------------------------------------------------
#
# 20/358, Reading File: V101_T116.parquet, New File Name: V101_T20
# 	 --> "V101_T20.parquet" saved.
# ------------------------------------------------------------
#
# 21/358, Reading File: V101_T117.parquet, New File Name: V101_T21
# 	 --> "V101_T21.parquet" saved.
# ------------------------------------------------------------
#
# 22/358, Reading File: V101_T118.parquet, New File Name: V101_T22
# 31.5
# 12.266242250000019
# 	 exceed indices: [0]
# 	Altitude jump of 31.5 detected at index 0
# 	 --> cut: 4.76 %
# 	 --> "V101_T22.parquet" saved.
# ------------------------------------------------------------
#
# 23/358, Reading File: V101_T119.parquet, New File Name: V101_T23
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T23.parquet" saved.
# ------------------------------------------------------------
#
# 24/358, Reading File: V101_T12.parquet, New File Name: V101_T24
# 	 --> "V101_T24.parquet" saved.
# ------------------------------------------------------------
#
# 25/358, Reading File: V101_T120.parquet, New File Name: V101_T25
# 	 --> "V101_T25.parquet" saved.
# ------------------------------------------------------------
#
# 26/358, Reading File: V101_T121.parquet, New File Name: V101_T26
# 	 --> "V101_T26.parquet" saved.
# ------------------------------------------------------------
#
# 27/358, Reading File: V101_T122.parquet, New File Name: V101_T27
# 	 --> "V101_T27.parquet" saved.
# ------------------------------------------------------------
#
# 28/358, Reading File: V101_T123.parquet, New File Name: V101_T28
# 	 --> "V101_T28.parquet" saved.
# ------------------------------------------------------------
#
# 29/358, Reading File: V101_T124.parquet, New File Name: V101_T29
# 	 --> "V101_T29.parquet" saved.
# ------------------------------------------------------------
#
# 30/358, Reading File: V101_T125.parquet, New File Name: V101_T30
# 	 --> "V101_T30.parquet" saved.
# ------------------------------------------------------------
#
# 31/358, Reading File: V101_T126.parquet, New File Name: V101_T31
# 	 --> "V101_T31.parquet" saved.
# ------------------------------------------------------------
#
# 32/358, Reading File: V101_T127.parquet, New File Name: V101_T32
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T32.parquet" saved.
# ------------------------------------------------------------
#
# 33/358, Reading File: V101_T128.parquet, New File Name: V101_T33
# 	 --> "V101_T33.parquet" saved.
# ------------------------------------------------------------
#
# 34/358, Reading File: V101_T129.parquet, New File Name: V101_T34
# 	 --> "V101_T34.parquet" saved.
# ------------------------------------------------------------
#
# 35/358, Reading File: V101_T13.parquet, New File Name: V101_T35
# 	 --> "V101_T35.parquet" saved.
# ------------------------------------------------------------
#
# 36/358, Reading File: V101_T130.parquet, New File Name: V101_T36
# 	 --> "V101_T36.parquet" saved.
# ------------------------------------------------------------
#
# 37/358, Reading File: V101_T131.parquet, New File Name: V101_T37
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T37.parquet" saved.
# ------------------------------------------------------------
#
# 38/358, Reading File: V101_T132.parquet, New File Name: V101_T38
# 	 --> "V101_T38.parquet" saved.
# ------------------------------------------------------------
#
# 39/358, Reading File: V101_T133.parquet, New File Name: V101_T39
# 	 --> "V101_T39.parquet" saved.
# ------------------------------------------------------------
#
# 40/358, Reading File: V101_T134.parquet, New File Name: V101_T40
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 149.0
# 6.199999997846817e-05
# 	 exceed indices: [0]
# 	Altitude jump of 149.0 detected at index 0
# 	 --> cut: 2.08 %
# 	 --> "V101_T40.parquet" saved.
# ------------------------------------------------------------
#
# 41/358, Reading File: V101_T135.parquet, New File Name: V101_T41
# 	 --> "V101_T41.parquet" saved.
# ------------------------------------------------------------
#
# 42/358, Reading File: V101_T136.parquet, New File Name: V101_T42
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T42.parquet" saved.
# ------------------------------------------------------------
#
# 43/358, Reading File: V101_T137.parquet, New File Name: V101_T43
# 	 --> "V101_T43.parquet" saved.
# ------------------------------------------------------------
#
# 44/358, Reading File: V101_T138.parquet, New File Name: V101_T44
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T44.parquet" saved.
# ------------------------------------------------------------
#
# 45/358, Reading File: V101_T139.parquet, New File Name: V101_T45
# 	 --> "V101_T45.parquet" saved.
# ------------------------------------------------------------
#
# 46/358, Reading File: V101_T14.parquet, New File Name: V101_T46
# 	 --> "V101_T46.parquet" saved.
# ------------------------------------------------------------
#
# 47/358, Reading File: V101_T140.parquet, New File Name: V101_T47
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T47.parquet" saved.
# ------------------------------------------------------------
#
# 48/358, Reading File: V101_T141.parquet, New File Name: V101_T48
# 	 --> "V101_T48.parquet" saved.
# ------------------------------------------------------------
#
# 49/358, Reading File: V101_T142.parquet, New File Name: V101_T49
# 	 --> "V101_T49.parquet" saved.
# ------------------------------------------------------------
#
# 50/358, Reading File: V101_T143.parquet, New File Name: V101_T50
# 	 --> "V101_T50.parquet" saved.
# ------------------------------------------------------------
#
# 51/358, Reading File: V101_T144.parquet, New File Name: V101_T51
# 	 --> "V101_T51.parquet" saved.
# ------------------------------------------------------------
#
# 52/358, Reading File: V101_T145.parquet, New File Name: V101_T52
# 	 --> "V101_T52.parquet" saved.
# ------------------------------------------------------------
#
# 53/358, Reading File: V101_T146.parquet, New File Name: V101_T53
# 	 --> "V101_T53.parquet" saved.
# ------------------------------------------------------------
#
# 54/358, Reading File: V101_T147.parquet, New File Name: V101_T54
# 	 --> "V101_T54.parquet" saved.
# ------------------------------------------------------------
#
# 55/358, Reading File: V101_T148.parquet, New File Name: V101_T55
# 	 --> "V101_T55.parquet" saved.
# ------------------------------------------------------------
#
# 56/358, Reading File: V101_T149.parquet, New File Name: V101_T56
# 	 --> "V101_T56.parquet" saved.
# ------------------------------------------------------------
#
# 57/358, Reading File: V101_T15.parquet, New File Name: V101_T57
# 	 --> "V101_T57.parquet" saved.
# ------------------------------------------------------------
#
# 58/358, Reading File: V101_T150.parquet, New File Name: V101_T58
# 	 --> "V101_T58.parquet" saved.
# ------------------------------------------------------------
#
# 59/358, Reading File: V101_T151.parquet, New File Name: V101_T59
# 	 --> "V101_T59.parquet" saved.
# ------------------------------------------------------------
#
# 60/358, Reading File: V101_T152.parquet, New File Name: V101_T60
# 	 --> "V101_T60.parquet" saved.
# ------------------------------------------------------------
#
# 61/358, Reading File: V101_T153.parquet, New File Name: V101_T61
# 	 --> "V101_T61.parquet" saved.
# ------------------------------------------------------------
#
# 62/358, Reading File: V101_T154.parquet, New File Name: V101_T62
# 	 --> "V101_T62.parquet" saved.
# ------------------------------------------------------------
#
# 63/358, Reading File: V101_T155.parquet, New File Name: V101_T63
# 	 --> "V101_T63.parquet" saved.
# ------------------------------------------------------------
#
# 64/358, Reading File: V101_T156.parquet, New File Name: V101_T64
# 	 --> "V101_T64.parquet" saved.
# ------------------------------------------------------------
#
# 65/358, Reading File: V101_T157.parquet, New File Name: V101_T65
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 648.3
# 0.0001656666666818296
# 	 exceed indices: [0]
# 	Altitude jump of 648.3 detected at index 0
# 	 --> cut: 2.24 %
# 	 --> "V101_T65.parquet" saved.
# ------------------------------------------------------------
#
# 66/358, Reading File: V101_T158.parquet, New File Name: V101_T66
# 	 --> "V101_T66.parquet" saved.
# ------------------------------------------------------------
#
# 67/358, Reading File: V101_T159.parquet, New File Name: V101_T67
# 	 --> "V101_T67.parquet" saved.
# ------------------------------------------------------------
#
# 68/358, Reading File: V101_T16.parquet, New File Name: V101_T68
# 	 --> "V101_T68.parquet" saved.
# ------------------------------------------------------------
#
# 69/358, Reading File: V101_T160.parquet, New File Name: V101_T69
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 721.125
# 0.00022000000001298758
# 	 exceed indices: [0]
# 	Altitude jump of 721.125 detected at index 0
# 	 --> cut: 0.12 %
# 	 --> "V101_T69.parquet" saved.
# ------------------------------------------------------------
#
# 70/358, Reading File: V101_T161.parquet, New File Name: V101_T70
# 	 --> "V101_T70.parquet" saved.
# ------------------------------------------------------------
#
# 71/358, Reading File: V101_T162.parquet, New File Name: V101_T71
# 	 --> "V101_T71.parquet" saved.
# ------------------------------------------------------------
#
# 72/358, Reading File: V101_T163.parquet, New File Name: V101_T72
# 	 --> "V101_T72.parquet" saved.
# ------------------------------------------------------------
#
# 73/358, Reading File: V101_T164.parquet, New File Name: V101_T73
# 	 --> "V101_T73.parquet" saved.
# ------------------------------------------------------------
#
# 74/358, Reading File: V101_T165.parquet, New File Name: V101_T74
# 	 --> "V101_T74.parquet" saved.
# ------------------------------------------------------------
#
# 75/358, Reading File: V101_T166.parquet, New File Name: V101_T75
# 	 --> "V101_T75.parquet" saved.
# ------------------------------------------------------------
#
# 76/358, Reading File: V101_T167.parquet, New File Name: V101_T76
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 1332.75
# 0.0001010000000007949
# 	 exceed indices: [0]
# 	Altitude jump of 1332.75 detected at index 0
# 	 --> cut: 0.38 %
# 	 --> "V101_T76.parquet" saved.
# ------------------------------------------------------------
#
# 77/358, Reading File: V101_T168.parquet, New File Name: V101_T77
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 1106.8125
# 0.00010366666668204516
# 	 exceed indices: [0]
# 	Altitude jump of 1106.8125 detected at index 0
# 	 --> cut: 0.28 %
# 	 --> "V101_T77.parquet" saved.
# ------------------------------------------------------------
#
# 78/358, Reading File: V101_T169.parquet, New File Name: V101_T78
# 	 --> "V101_T78.parquet" saved.
# ------------------------------------------------------------
#
# 79/358, Reading File: V101_T17.parquet, New File Name: V101_T79
# 	 --> "V101_T79.parquet" saved.
# ------------------------------------------------------------
#
# 80/358, Reading File: V101_T170.parquet, New File Name: V101_T80
# 	 --> "V101_T80.parquet" saved.
# ------------------------------------------------------------
#
# 81/358, Reading File: V101_T171.parquet, New File Name: V101_T81
# 	 --> "V101_T81.parquet" saved.
# ------------------------------------------------------------
#
# 82/358, Reading File: V101_T172.parquet, New File Name: V101_T82
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 1322.25
# 0.00010900000000901855
# 	 exceed indices: [0]
# 	Altitude jump of 1322.25 detected at index 0
# 	 --> cut: 0.34 %
# 	 --> "V101_T82.parquet" saved.
# ------------------------------------------------------------
#
# 83/358, Reading File: V101_T173.parquet, New File Name: V101_T83
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 1681.625
# 0.00010299999999574538
# 	 exceed indices: [0]
# 	Altitude jump of 1681.625 detected at index 0
# 	 --> cut: 0.31 %
# 	 --> "V101_T83.parquet" saved.
# ------------------------------------------------------------
#
# 84/358, Reading File: V101_T174.parquet, New File Name: V101_T84
# 	 --> "V101_T84.parquet" saved.
# ------------------------------------------------------------
#
# 85/358, Reading File: V101_T175.parquet, New File Name: V101_T85
# 	 --> "V101_T85.parquet" saved.
# ------------------------------------------------------------
#
# 86/358, Reading File: V101_T176.parquet, New File Name: V101_T86
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 1323.875
# 9.300000002099296e-05
# 	 exceed indices: [0]
# 	Altitude jump of 1323.875 detected at index 0
# 	 --> cut: 0.39 %
# 	 --> "V101_T86.parquet" saved.
# ------------------------------------------------------------
#
# 87/358, Reading File: V101_T177.parquet, New File Name: V101_T87
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 1678.5
# 0.00010399999999322063
# 	 exceed indices: [0]
# 	Altitude jump of 1678.5 detected at index 0
# 	 --> cut: 0.31 %
# 	 --> "V101_T87.parquet" saved.
# ------------------------------------------------------------
#
# 88/358, Reading File: V101_T178.parquet, New File Name: V101_T88
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 2145.125
# 0.00013700000002359047
# 	 exceed indices: [0]
# 	Altitude jump of 2145.125 detected at index 0
# 	 --> cut: 0.15 %
# 	 --> "V101_T88.parquet" saved.
# ------------------------------------------------------------
#
# 89/358, Reading File: V101_T179.parquet, New File Name: V101_T89
# 	 --> "V101_T89.parquet" saved.
# ------------------------------------------------------------
#
# 90/358, Reading File: V101_T18.parquet, New File Name: V101_T90
# 134.5
# 0.0002380000000314908
# 	 exceed indices: [0]
# 	Altitude jump of 134.5 detected at index 0
# 	 --> cut: 2.38 %
# 	 --> "V101_T90.parquet" saved.
# ------------------------------------------------------------
#
# 91/358, Reading File: V101_T180.parquet, New File Name: V101_T91
# 	 --> "V101_T91.parquet" saved.
# ------------------------------------------------------------
#
# 92/358, Reading File: V101_T181.parquet, New File Name: V101_T92
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T92.parquet" saved.
# ------------------------------------------------------------
#
# 93/358, Reading File: V101_T182.parquet, New File Name: V101_T93
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 558.4166666666667
# 0.00010400000000032605
# 	 exceed indices: [0]
# 	Altitude jump of 558.4166666666667 detected at index 0
# 	 --> cut: 0.30 %
# 	 --> "V101_T93.parquet" saved.
# ------------------------------------------------------------
#
# 94/358, Reading File: V101_T183.parquet, New File Name: V101_T94
# 	 --> "V101_T94.parquet" saved.
# ------------------------------------------------------------
#
# 95/358, Reading File: V101_T184.parquet, New File Name: V101_T95
# 	 --> "V101_T95.parquet" saved.
# ------------------------------------------------------------
#
# 96/358, Reading File: V101_T185.parquet, New File Name: V101_T96
# 	 --> "V101_T96.parquet" saved.
# ------------------------------------------------------------
#
# 97/358, Reading File: V101_T186.parquet, New File Name: V101_T97
# 	 --> "V101_T97.parquet" saved.
# ------------------------------------------------------------
#
# 98/358, Reading File: V101_T187.parquet, New File Name: V101_T98
# 	 --> "V101_T98.parquet" saved.
# ------------------------------------------------------------
#
# 99/358, Reading File: V101_T188.parquet, New File Name: V101_T99
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 689.0
# 0.003916999999994175
# 	 exceed indices: [0]
# 	Altitude jump of 689.0 detected at index 0
# 	 --> cut: 0.08 %
# 	 --> "V101_T99.parquet" saved.
# ------------------------------------------------------------
#
# 100/358, Reading File: V101_T189.parquet, New File Name: V101_T100
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 2176.625
# 0.0036949999999933425
# 	 exceed indices: [0]
# 	Altitude jump of 2176.625 detected at index 0
# 	 --> cut: 0.09 %
# 	 --> "V101_T100.parquet" saved.
# ------------------------------------------------------------
#
# 101/358, Reading File: V101_T19.parquet, New File Name: V101_T101
# 	 --> "V101_T101.parquet" saved.
# ------------------------------------------------------------
#
# 102/358, Reading File: V101_T190.parquet, New File Name: V101_T102
# 	 --> "V101_T102.parquet" saved.
# ------------------------------------------------------------
#
# 103/358, Reading File: V101_T191.parquet, New File Name: V101_T103
# 	 --> "V101_T103.parquet" saved.
# ------------------------------------------------------------
#
# 104/358, Reading File: V101_T192.parquet, New File Name: V101_T104
# 	 --> "V101_T104.parquet" saved.
# ------------------------------------------------------------
#
# 105/358, Reading File: V101_T193.parquet, New File Name: V101_T105
# 	 --> "V101_T105.parquet" saved.
# ------------------------------------------------------------
#
# 106/358, Reading File: V101_T194.parquet, New File Name: V101_T106
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 677.0
# 0.003987999999985448
# 	 exceed indices: [0]
# 	Altitude jump of 677.0 detected at index 0
# 	 --> cut: 0.10 %
# 	 --> "V101_T106.parquet" saved.
# ------------------------------------------------------------
#
# 107/358, Reading File: V101_T195.parquet, New File Name: V101_T107
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 2169.25
# 0.0036169999999913216
# 	 exceed indices: [0]
# 	Altitude jump of 2169.25 detected at index 0
# 	 --> cut: 0.10 %
# 	 --> "V101_T107.parquet" saved.
# ------------------------------------------------------------
#
# 108/358, Reading File: V101_T196.parquet, New File Name: V101_T108
# 	 --> "V101_T108.parquet" saved.
# ------------------------------------------------------------
#
# 109/358, Reading File: V101_T197.parquet, New File Name: V101_T109
# 	 --> "V101_T109.parquet" saved.
# ------------------------------------------------------------
#
# 110/358, Reading File: V101_T198.parquet, New File Name: V101_T110
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 771.8916666666667
# 0.0002512500000051432
# 	 exceed indices: [0]
# 	Altitude jump of 771.8916666666667 detected at index 0
# 	 --> cut: 0.07 %
# 	 --> "V101_T110.parquet" saved.
# ------------------------------------------------------------
#
# 111/358, Reading File: V101_T199.parquet, New File Name: V101_T111
# 	 --> "V101_T111.parquet" saved.
# ------------------------------------------------------------
#
# 112/358, Reading File: V101_T2.parquet, New File Name: V101_T112
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 313.41249999999997
# 0.00013209999997343402
# 	 exceed indices: [0]
# 	Altitude jump of 313.41249999999997 detected at index 0
# 	 --> cut: 0.86 %
# 	 --> "V101_T112.parquet" saved.
# ------------------------------------------------------------
#
# 113/358, Reading File: V101_T20.parquet, New File Name: V101_T113
# 	 --> "V101_T113.parquet" saved.
# ------------------------------------------------------------
#
# 114/358, Reading File: V101_T200.parquet, New File Name: V101_T114
# 	 --> "V101_T114.parquet" saved.
# ------------------------------------------------------------
#
# 115/358, Reading File: V101_T201.parquet, New File Name: V101_T115
# 	 --> "V101_T115.parquet" saved.
# ------------------------------------------------------------
#
# 116/358, Reading File: V101_T202.parquet, New File Name: V101_T116
# 	 --> "V101_T116.parquet" saved.
# ------------------------------------------------------------
#
# 117/358, Reading File: V101_T203.parquet, New File Name: V101_T117
# 	 --> "V101_T117.parquet" saved.
# ------------------------------------------------------------
#
# 118/358, Reading File: V101_T204.parquet, New File Name: V101_T118
# 	 --> "V101_T118.parquet" saved.
# ------------------------------------------------------------
#
# 119/358, Reading File: V101_T205.parquet, New File Name: V101_T119
# 	 --> "V101_T119.parquet" saved.
# ------------------------------------------------------------
#
# 120/358, Reading File: V101_T206.parquet, New File Name: V101_T120
# 	 --> "V101_T120.parquet" saved.
# ------------------------------------------------------------
#
# 121/358, Reading File: V101_T207.parquet, New File Name: V101_T121
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 535.78125
# 0.0025760000000047967
# 	 exceed indices: [0]
# 	Altitude jump of 535.78125 detected at index 0
# 	 --> cut: 0.09 %
# 	 --> "V101_T121.parquet" saved.
# ------------------------------------------------------------
#
# 122/358, Reading File: V101_T208.parquet, New File Name: V101_T122
# 	 --> "V101_T122.parquet" saved.
# ------------------------------------------------------------
#
# 123/358, Reading File: V101_T209.parquet, New File Name: V101_T123
# 	 --> "V101_T123.parquet" saved.
# ------------------------------------------------------------
#
# 124/358, Reading File: V101_T21.parquet, New File Name: V101_T124
# 	 --> "V101_T124.parquet" saved.
# ------------------------------------------------------------
#
# 125/358, Reading File: V101_T210.parquet, New File Name: V101_T125
# 	Signal elcomp_pwrcons_cval clipped to range (0, 14)
# 	 --> "V101_T125.parquet" saved.
# ------------------------------------------------------------
#
# 126/358, Reading File: V101_T211.parquet, New File Name: V101_T126
# 	 --> "V101_T126.parquet" saved.
# ------------------------------------------------------------
#
# 127/358, Reading File: V101_T212.parquet, New File Name: V101_T127
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 845.5833333333333
# 0.0001469999999983429
# 	 exceed indices: [0]
# 	Altitude jump of 845.5833333333333 detected at index 0
# 	 --> cut: 0.23 %
# 	 --> "V101_T127.parquet" saved.
# ------------------------------------------------------------
#
# 128/358, Reading File: V101_T213.parquet, New File Name: V101_T128
# 	 --> "V101_T128.parquet" saved.
# ------------------------------------------------------------
#
# 129/358, Reading File: V101_T214.parquet, New File Name: V101_T129
# 	 --> "V101_T129.parquet" saved.
# ------------------------------------------------------------
#
# 130/358, Reading File: V101_T215.parquet, New File Name: V101_T130
# 	 --> "V101_T130.parquet" saved.
# ------------------------------------------------------------
#
# 131/358, Reading File: V101_T216.parquet, New File Name: V101_T131
# 	 --> "V101_T131.parquet" saved.
# ------------------------------------------------------------
#
# 132/358, Reading File: V101_T217.parquet, New File Name: V101_T132
# 	 --> "V101_T132.parquet" saved.
# ------------------------------------------------------------
#
# 133/358, Reading File: V101_T218.parquet, New File Name: V101_T133
# 	 --> "V101_T133.parquet" saved.
# ------------------------------------------------------------
#
# 134/358, Reading File: V101_T219.parquet, New File Name: V101_T134
# 	 --> "V101_T134.parquet" saved.
# ------------------------------------------------------------
#
# 135/358, Reading File: V101_T22.parquet, New File Name: V101_T135
# 	 --> "V101_T135.parquet" saved.
# ------------------------------------------------------------
#
# 136/358, Reading File: V101_T220.parquet, New File Name: V101_T136
# 	 --> "V101_T136.parquet" saved.
# ------------------------------------------------------------
#
# 137/358, Reading File: V101_T221.parquet, New File Name: V101_T137
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 2153.5
# 0.0001540000000090913
# 	 exceed indices: [0]
# 	Altitude jump of 2153.5 detected at index 0
# 	 --> cut: 0.17 %
# 	 --> "V101_T137.parquet" saved.
# ------------------------------------------------------------
#
# 138/358, Reading File: V101_T222.parquet, New File Name: V101_T138
# 	 --> "V101_T138.parquet" saved.
# ------------------------------------------------------------
#
# 139/358, Reading File: V101_T223.parquet, New File Name: V101_T139
# 	 --> "V101_T139.parquet" saved.
# ------------------------------------------------------------
#
# 140/358, Reading File: V101_T224.parquet, New File Name: V101_T140
# 	 --> "V101_T140.parquet" saved.
# ------------------------------------------------------------
#
# 141/358, Reading File: V101_T225.parquet, New File Name: V101_T141
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 2169.5
# 0.003652000000016642
# 	 exceed indices: [0]
# 	Altitude jump of 2169.5 detected at index 0
# 	 --> cut: 0.07 %
# 	 --> "V101_T141.parquet" saved.
# ------------------------------------------------------------
#
# 142/358, Reading File: V101_T226.parquet, New File Name: V101_T142
# 	 --> "V101_T142.parquet" saved.
# ------------------------------------------------------------
#
# 143/358, Reading File: V101_T227.parquet, New File Name: V101_T143
# 	 --> "V101_T143.parquet" saved.
# ------------------------------------------------------------
#
# 144/358, Reading File: V101_T228.parquet, New File Name: V101_T144
# 	 --> "V101_T144.parquet" saved.
# ------------------------------------------------------------
#
# 145/358, Reading File: V101_T229.parquet, New File Name: V101_T145
# 	 --> "V101_T145.parquet" saved.
# ------------------------------------------------------------
#
# 146/358, Reading File: V101_T23.parquet, New File Name: V101_T146
# 	 --> "V101_T146.parquet" saved.
# ------------------------------------------------------------
#
# 147/358, Reading File: V101_T230.parquet, New File Name: V101_T147
# 	 --> "V101_T147.parquet" saved.
# ------------------------------------------------------------
#
# 148/358, Reading File: V101_T231.parquet, New File Name: V101_T148
# 	 --> "V101_T148.parquet" saved.
# ------------------------------------------------------------
#
# 149/358, Reading File: V101_T232.parquet, New File Name: V101_T149
# 	 --> "V101_T149.parquet" saved.
# ------------------------------------------------------------
#
# 150/358, Reading File: V101_T233.parquet, New File Name: V101_T150
# 	 --> "V101_T150.parquet" saved.
# ------------------------------------------------------------
#
# 151/358, Reading File: V101_T234.parquet, New File Name: V101_T151
# 	 --> "V101_T151.parquet" saved.
# ------------------------------------------------------------
#
# 152/358, Reading File: V101_T235.parquet, New File Name: V101_T152
# 	 --> "V101_T152.parquet" saved.
# ------------------------------------------------------------
#
# 153/358, Reading File: V101_T236.parquet, New File Name: V101_T153
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 344.22916666666663
# 0.003982000000014807
# 	 exceed indices: [0]
# 	Altitude jump of 344.22916666666663 detected at index 0
# 	 --> cut: 0.08 %
# 	 --> "V101_T153.parquet" saved.
# ------------------------------------------------------------
#
# 154/358, Reading File: V101_T237.parquet, New File Name: V101_T154
# 	 --> "V101_T154.parquet" saved.
# ------------------------------------------------------------
#
# 155/358, Reading File: V101_T238.parquet, New File Name: V101_T155
# 	 --> "V101_T155.parquet" saved.
# ------------------------------------------------------------
#
# 156/358, Reading File: V101_T239.parquet, New File Name: V101_T156
# 	 --> "V101_T156.parquet" saved.
# ------------------------------------------------------------
#
# 157/358, Reading File: V101_T24.parquet, New File Name: V101_T157
# 	 --> "V101_T157.parquet" saved.
# ------------------------------------------------------------
#
# 158/358, Reading File: V101_T240.parquet, New File Name: V101_T158
# 	 --> "V101_T158.parquet" saved.
# ------------------------------------------------------------
#
# 159/358, Reading File: V101_T241.parquet, New File Name: V101_T159
# 	 --> "V101_T159.parquet" saved.
# ------------------------------------------------------------
#
# 160/358, Reading File: V101_T242.parquet, New File Name: V101_T160
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T160.parquet" saved.
# ------------------------------------------------------------
#
# 161/358, Reading File: V101_T243.parquet, New File Name: V101_T161
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T161.parquet" saved.
# ------------------------------------------------------------
#
# 162/358, Reading File: V101_T244.parquet, New File Name: V101_T162
# 	 --> "V101_T162.parquet" saved.
# ------------------------------------------------------------
#
# 163/358, Reading File: V101_T245.parquet, New File Name: V101_T163
# 	 --> "V101_T163.parquet" saved.
# ------------------------------------------------------------
#
# 164/358, Reading File: V101_T246.parquet, New File Name: V101_T164
# 	 --> "V101_T164.parquet" saved.
# ------------------------------------------------------------
#
# 165/358, Reading File: V101_T247.parquet, New File Name: V101_T165
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 225.5625
# 9.7666666668772e-05
# 	 exceed indices: [0]
# 	Altitude jump of 225.5625 detected at index 0
# 	 --> cut: 0.92 %
# 	 --> "V101_T165.parquet" saved.
# ------------------------------------------------------------
#
# 166/358, Reading File: V101_T248.parquet, New File Name: V101_T166
# 	 --> "V101_T166.parquet" saved.
# ------------------------------------------------------------
#
# 167/358, Reading File: V101_T249.parquet, New File Name: V101_T167
# 	 --> "V101_T167.parquet" saved.
# ------------------------------------------------------------
#
# 168/358, Reading File: V101_T25.parquet, New File Name: V101_T168
# 	 --> "V101_T168.parquet" saved.
# ------------------------------------------------------------
#
# 169/358, Reading File: V101_T250.parquet, New File Name: V101_T169
# 	 --> "V101_T169.parquet" saved.
# ------------------------------------------------------------
#
# 170/358, Reading File: V101_T251.parquet, New File Name: V101_T170
# 	 --> "V101_T170.parquet" saved.
# ------------------------------------------------------------
#
# 171/358, Reading File: V101_T252.parquet, New File Name: V101_T171
# 	 --> "V101_T171.parquet" saved.
# ------------------------------------------------------------
#
# 172/358, Reading File: V101_T253.parquet, New File Name: V101_T172
# 	 --> "V101_T172.parquet" saved.
# ------------------------------------------------------------
#
# 173/358, Reading File: V101_T254.parquet, New File Name: V101_T173
# 	 --> "V101_T173.parquet" saved.
# ------------------------------------------------------------
#
# 174/358, Reading File: V101_T255.parquet, New File Name: V101_T174
# 	 --> "V101_T174.parquet" saved.
# ------------------------------------------------------------
#
# 175/358, Reading File: V101_T256.parquet, New File Name: V101_T175
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 1023.375
# 0.0017899999999997362
# 	 exceed indices: [0]
# 	Altitude jump of 1023.375 detected at index 0
# 	 --> cut: 0.04 %
# 	 --> "V101_T175.parquet" saved.
# ------------------------------------------------------------
#
# 176/358, Reading File: V101_T257.parquet, New File Name: V101_T176
# 	 --> "V101_T176.parquet" saved.
# ------------------------------------------------------------
#
# 177/358, Reading File: V101_T258.parquet, New File Name: V101_T177
# 	 --> "V101_T177.parquet" saved.
# ------------------------------------------------------------
#
# 178/358, Reading File: V101_T259.parquet, New File Name: V101_T178
# 	 --> "V101_T178.parquet" saved.
# ------------------------------------------------------------
#
# 179/358, Reading File: V101_T26.parquet, New File Name: V101_T179
# 148.46875
# 11.832884249999978
# 	 exceed indices: [0]
# 	Altitude jump of 148.46875 detected at index 0
# 	 --> cut: 0.28 %
# 	 --> "V101_T179.parquet" saved.
# ------------------------------------------------------------
#
# 180/358, Reading File: V101_T260.parquet, New File Name: V101_T180
# 	 --> "V101_T180.parquet" saved.
# ------------------------------------------------------------
#
# 181/358, Reading File: V101_T261.parquet, New File Name: V101_T181
# 	 --> "V101_T181.parquet" saved.
# ------------------------------------------------------------
#
# 182/358, Reading File: V101_T262.parquet, New File Name: V101_T182
# 	 --> "V101_T182.parquet" saved.
# ------------------------------------------------------------
#
# 183/358, Reading File: V101_T263.parquet, New File Name: V101_T183
# 	 --> "V101_T183.parquet" saved.
# ------------------------------------------------------------
#
# 184/358, Reading File: V101_T264.parquet, New File Name: V101_T184
# 	Signal elcomp_pwrcons_cval clipped to range (0, 14)
# 	 --> "V101_T184.parquet" saved.
# ------------------------------------------------------------
#
# 185/358, Reading File: V101_T265.parquet, New File Name: V101_T185
# 	 --> "V101_T185.parquet" saved.
# ------------------------------------------------------------
#
# 186/358, Reading File: V101_T266.parquet, New File Name: V101_T186
# 	 --> "V101_T186.parquet" saved.
# ------------------------------------------------------------
#
# 187/358, Reading File: V101_T267.parquet, New File Name: V101_T187
# 	 --> "V101_T187.parquet" saved.
# ------------------------------------------------------------
#
# 188/358, Reading File: V101_T268.parquet, New File Name: V101_T188
# 	 --> "V101_T188.parquet" saved.
# ------------------------------------------------------------
#
# 189/358, Reading File: V101_T269.parquet, New File Name: V101_T189
# 	 --> "V101_T189.parquet" saved.
# ------------------------------------------------------------
#
# 190/358, Reading File: V101_T27.parquet, New File Name: V101_T190
# 	 --> "V101_T190.parquet" saved.
# ------------------------------------------------------------
#
# 191/358, Reading File: V101_T270.parquet, New File Name: V101_T191
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 189.5
# 0.00022000000000588216
# 	 exceed indices: [0]
# 	Altitude jump of 189.5 detected at index 0
# 	 --> cut: 0.03 %
# 	 --> "V101_T191.parquet" saved.
# ------------------------------------------------------------
#
# 192/358, Reading File: V101_T271.parquet, New File Name: V101_T192
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T192.parquet" saved.
# ------------------------------------------------------------
#
# 193/358, Reading File: V101_T272.parquet, New File Name: V101_T193
# 	 --> "V101_T193.parquet" saved.
# ------------------------------------------------------------
#
# 194/358, Reading File: V101_T273.parquet, New File Name: V101_T194
# 	 --> "V101_T194.parquet" saved.
# ------------------------------------------------------------
#
# 195/358, Reading File: V101_T274.parquet, New File Name: V101_T195
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 465.625
# 0.0003190000000472537
# 	 exceed indices: [0]
# 	Altitude jump of 465.625 detected at index 0
# 	 --> cut: 0.13 %
# 	 --> "V101_T195.parquet" saved.
# ------------------------------------------------------------
#
# 196/358, Reading File: V101_T275.parquet, New File Name: V101_T196
# 	 --> "V101_T196.parquet" saved.
# ------------------------------------------------------------
#
# 197/358, Reading File: V101_T276.parquet, New File Name: V101_T197
# 	 --> "V101_T197.parquet" saved.
# ------------------------------------------------------------
#
# 198/358, Reading File: V101_T277.parquet, New File Name: V101_T198
# 	 --> "V101_T198.parquet" saved.
# ------------------------------------------------------------
#
# 199/358, Reading File: V101_T278.parquet, New File Name: V101_T199
# 	 --> "V101_T199.parquet" saved.
# ------------------------------------------------------------
#
# 200/358, Reading File: V101_T279.parquet, New File Name: V101_T200
# 	 --> "V101_T200.parquet" saved.
# ------------------------------------------------------------
#
# 201/358, Reading File: V101_T28.parquet, New File Name: V101_T201
# 149.75
# 11.81901775
# 	 exceed indices: [0]
# 	Altitude jump of 149.75 detected at index 0
# 	 --> cut: 0.59 %
# 	 --> "V101_T201.parquet" saved.
# ------------------------------------------------------------
#
# 202/358, Reading File: V101_T280.parquet, New File Name: V101_T202
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T202.parquet" saved.
# ------------------------------------------------------------
#
# 203/358, Reading File: V101_T281.parquet, New File Name: V101_T203
# 	 --> "V101_T203.parquet" saved.
# ------------------------------------------------------------
#
# 204/358, Reading File: V101_T282.parquet, New File Name: V101_T204
# 	 --> "V101_T204.parquet" saved.
# ------------------------------------------------------------
#
# 205/358, Reading File: V101_T283.parquet, New File Name: V101_T205
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 129.625
# 0.01703499999995728
# 	 exceed indices: [0]
# 	Altitude jump of 129.625 detected at index 0
# 	 --> cut: 0.05 %
# 	 --> "V101_T205.parquet" saved.
# ------------------------------------------------------------
#
# 206/358, Reading File: V101_T284.parquet, New File Name: V101_T206
# 	 --> "V101_T206.parquet" saved.
# ------------------------------------------------------------
#
# 207/358, Reading File: V101_T285.parquet, New File Name: V101_T207
# 	 --> "V101_T207.parquet" saved.
# ------------------------------------------------------------
#
# 208/358, Reading File: V101_T286.parquet, New File Name: V101_T208
# 	 --> "V101_T208.parquet" saved.
# ------------------------------------------------------------
#
# 209/358, Reading File: V101_T287.parquet, New File Name: V101_T209
# 	 --> "V101_T209.parquet" saved.
# ------------------------------------------------------------
#
# 210/358, Reading File: V101_T288.parquet, New File Name: V101_T210
# 	 --> "V101_T210.parquet" saved.
# ------------------------------------------------------------
#
# 211/358, Reading File: V101_T289.parquet, New File Name: V101_T211
# 	 --> "V101_T211.parquet" saved.
# ------------------------------------------------------------
#
# 212/358, Reading File: V101_T29.parquet, New File Name: V101_T212
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 961.25
# 0.007689999999968222
# 	 exceed indices: [0]
# 	Altitude jump of 961.25 detected at index 0
# 	 --> cut: 0.05 %
# 	 --> "V101_T212.parquet" saved.
# ------------------------------------------------------------
#
# 213/358, Reading File: V101_T290.parquet, New File Name: V101_T213
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T213.parquet" saved.
# ------------------------------------------------------------
#
# 214/358, Reading File: V101_T291.parquet, New File Name: V101_T214
# 	 --> "V101_T214.parquet" saved.
# ------------------------------------------------------------
#
# 215/358, Reading File: V101_T292.parquet, New File Name: V101_T215
# 	 --> "V101_T215.parquet" saved.
# ------------------------------------------------------------
#
# 216/358, Reading File: V101_T293.parquet, New File Name: V101_T216
# 	 --> "V101_T216.parquet" saved.
# ------------------------------------------------------------
#
# 217/358, Reading File: V101_T294.parquet, New File Name: V101_T217
# 	 --> "V101_T217.parquet" saved.
# ------------------------------------------------------------
#
# 218/358, Reading File: V101_T295.parquet, New File Name: V101_T218
# 	 --> "V101_T218.parquet" saved.
# ------------------------------------------------------------
#
# 219/358, Reading File: V101_T296.parquet, New File Name: V101_T219
# 	 --> "V101_T219.parquet" saved.
# ------------------------------------------------------------
#
# 220/358, Reading File: V101_T297.parquet, New File Name: V101_T220
# 	 --> "V101_T220.parquet" saved.
# ------------------------------------------------------------
#
# 221/358, Reading File: V101_T298.parquet, New File Name: V101_T221
# 	 --> "V101_T221.parquet" saved.
# ------------------------------------------------------------
#
# 222/358, Reading File: V101_T299.parquet, New File Name: V101_T222
# 	 --> "V101_T222.parquet" saved.
# ------------------------------------------------------------
#
# 223/358, Reading File: V101_T3.parquet, New File Name: V101_T223
# 	 --> "V101_T223.parquet" saved.
# ------------------------------------------------------------
#
# 224/358, Reading File: V101_T30.parquet, New File Name: V101_T224
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 786.03125
# 0.007537999999989609
# 	 exceed indices: [0]
# 	Altitude jump of 786.03125 detected at index 0
# 	 --> cut: 0.02 %
# 	 --> "V101_T224.parquet" saved.
# ------------------------------------------------------------
#
# 225/358, Reading File: V101_T300.parquet, New File Name: V101_T225
# 	 --> "V101_T225.parquet" saved.
# ------------------------------------------------------------
#
# 226/358, Reading File: V101_T301.parquet, New File Name: V101_T226
# 	 --> "V101_T226.parquet" saved.
# ------------------------------------------------------------
#
# 227/358, Reading File: V101_T302.parquet, New File Name: V101_T227
# 	 --> "V101_T227.parquet" saved.
# ------------------------------------------------------------
#
# 228/358, Reading File: V101_T303.parquet, New File Name: V101_T228
# 	 --> "V101_T228.parquet" saved.
# ------------------------------------------------------------
#
# 229/358, Reading File: V101_T304.parquet, New File Name: V101_T229
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T229.parquet" saved.
# ------------------------------------------------------------
#
# 230/358, Reading File: V101_T305.parquet, New File Name: V101_T230
# 	 --> "V101_T230.parquet" saved.
# ------------------------------------------------------------
#
# 231/358, Reading File: V101_T306.parquet, New File Name: V101_T231
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T231.parquet" saved.
# ------------------------------------------------------------
#
# 232/358, Reading File: V101_T307.parquet, New File Name: V101_T232
# 	 --> "V101_T232.parquet" saved.
# ------------------------------------------------------------
#
# 233/358, Reading File: V101_T308.parquet, New File Name: V101_T233
# 	 --> "V101_T233.parquet" saved.
# ------------------------------------------------------------
#
# 234/358, Reading File: V101_T309.parquet, New File Name: V101_T234
# 	 --> "V101_T234.parquet" saved.
# ------------------------------------------------------------
#
# 235/358, Reading File: V101_T31.parquet, New File Name: V101_T235
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T235.parquet" saved.
# ------------------------------------------------------------
#
# 236/358, Reading File: V101_T310.parquet, New File Name: V101_T236
# 	 --> "V101_T236.parquet" saved.
# ------------------------------------------------------------
#
# 237/358, Reading File: V101_T311.parquet, New File Name: V101_T237
# 	 --> "V101_T237.parquet" saved.
# ------------------------------------------------------------
#
# 238/358, Reading File: V101_T312.parquet, New File Name: V101_T238
# 	 --> "V101_T238.parquet" saved.
# ------------------------------------------------------------
#
# 239/358, Reading File: V101_T313.parquet, New File Name: V101_T239
# 	 --> "V101_T239.parquet" saved.
# ------------------------------------------------------------
#
# 240/358, Reading File: V101_T314.parquet, New File Name: V101_T240
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 234.5
# 0.009095000000002074
# 	 exceed indices: [0]
# 	Altitude jump of 234.5 detected at index 0
# 	 --> cut: 0.05 %
# 	 --> "V101_T240.parquet" saved.
# ------------------------------------------------------------
#
# 241/358, Reading File: V101_T315.parquet, New File Name: V101_T241
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 144.25
# 9.399999999004649e-05
# 	 exceed indices: [0]
# 	Altitude jump of 144.25 detected at index 0
# 	 --> cut: 2.56 %
# 	 --> "V101_T241.parquet" saved.
# ------------------------------------------------------------
#
# 242/358, Reading File: V101_T316.parquet, New File Name: V101_T242
# 	 --> "V101_T242.parquet" saved.
# ------------------------------------------------------------
#
# 243/358, Reading File: V101_T317.parquet, New File Name: V101_T243
# 	 --> "V101_T243.parquet" saved.
# ------------------------------------------------------------
#
# 244/358, Reading File: V101_T318.parquet, New File Name: V101_T244
# 	 --> "V101_T244.parquet" saved.
# ------------------------------------------------------------
#
# 245/358, Reading File: V101_T319.parquet, New File Name: V101_T245
# 	 --> "V101_T245.parquet" saved.
# ------------------------------------------------------------
#
# 246/358, Reading File: V101_T32.parquet, New File Name: V101_T246
# 	 --> "V101_T246.parquet" saved.
# ------------------------------------------------------------
#
# 247/358, Reading File: V101_T320.parquet, New File Name: V101_T247
# 	 --> "V101_T247.parquet" saved.
# ------------------------------------------------------------
#
# 248/358, Reading File: V101_T321.parquet, New File Name: V101_T248
# 	 --> "V101_T248.parquet" saved.
# ------------------------------------------------------------
#
# 249/358, Reading File: V101_T322.parquet, New File Name: V101_T249
# 	 --> "V101_T249.parquet" saved.
# ------------------------------------------------------------
#
# 250/358, Reading File: V101_T323.parquet, New File Name: V101_T250
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 833.125
# 0.00012800000001078615
# 	 exceed indices: [0]
# 	Altitude jump of 833.125 detected at index 0
# 	 --> cut: 0.24 %
# 	 --> "V101_T250.parquet" saved.
# ------------------------------------------------------------
#
# 251/358, Reading File: V101_T324.parquet, New File Name: V101_T251
# 	 --> "V101_T251.parquet" saved.
# ------------------------------------------------------------
#
# 252/358, Reading File: V101_T325.parquet, New File Name: V101_T252
# 	 --> "V101_T252.parquet" saved.
# ------------------------------------------------------------
#
# 253/358, Reading File: V101_T326.parquet, New File Name: V101_T253
# 	 --> "V101_T253.parquet" saved.
# ------------------------------------------------------------
#
# 254/358, Reading File: V101_T327.parquet, New File Name: V101_T254
# 	 --> "V101_T254.parquet" saved.
# ------------------------------------------------------------
#
# ...
# ------------------------------------------------------------
#
# 281/358, Reading File: V101_T351.parquet, New File Name: V101_T281
# 	 --> "V101_T281.parquet" saved.
# ------------------------------------------------------------
#
# 282/358, Reading File: V101_T352.parquet, New File Name: V101_T282
# 	 --> "V101_T282.parquet" saved.
# ------------------------------------------------------------
#
# 283/358, Reading File: V101_T353.parquet, New File Name: V101_T283
# 	 --> "V101_T283.parquet" saved.
# ------------------------------------------------------------
#
# 284/358, Reading File: V101_T354.parquet, New File Name: V101_T284
# 	 --> "V101_T284.parquet" saved.
# ------------------------------------------------------------
#
# 285/358, Reading File: V101_T355.parquet, New File Name: V101_T285
# 	 --> "V101_T285.parquet" saved.
# ------------------------------------------------------------
#
# 286/358, Reading File: V101_T356.parquet, New File Name: V101_T286
# 	 --> "V101_T286.parquet" saved.
# ------------------------------------------------------------
#
# 287/358, Reading File: V101_T357.parquet, New File Name: V101_T287
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T287.parquet" saved.
# ------------------------------------------------------------
#
# 288/358, Reading File: V101_T358.parquet, New File Name: V101_T288
# 	 --> "V101_T288.parquet" saved.
# ------------------------------------------------------------
#
# 289/358, Reading File: V101_T36.parquet, New File Name: V101_T289
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 128.75
# 0.00021700000002766728
# 	 exceed indices: [0]
# 	Altitude jump of 128.75 detected at index 0
# 	 --> cut: 0.67 %
# 	 --> "V101_T289.parquet" saved.
# ------------------------------------------------------------
#
# 290/358, Reading File: V101_T37.parquet, New File Name: V101_T290
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 121.25
# 7.200000004559115e-05
# 	 exceed indices: [0]
# 	Altitude jump of 121.25 detected at index 0
# 	 --> cut: 4.84 %
# 	 --> "V101_T290.parquet" saved.
# ------------------------------------------------------------
#
# 291/358, Reading File: V101_T38.parquet, New File Name: V101_T291
# 	 --> "V101_T291.parquet" saved.
# ------------------------------------------------------------
#
# 292/358, Reading File: V101_T39.parquet, New File Name: V101_T292
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 131.875
# 5.8000000024094334e-05
# 	 exceed indices: [0]
# 	Altitude jump of 131.875 detected at index 0
# 	 --> cut: 3.45 %
# 	 --> "V101_T292.parquet" saved.
# ------------------------------------------------------------
#
# 293/358, Reading File: V101_T4.parquet, New File Name: V101_T293
# 	 --> "V101_T293.parquet" saved.
# ------------------------------------------------------------
#
# 294/358, Reading File: V101_T40.parquet, New File Name: V101_T294
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 128.875
# 0.00020699999998186058
# 	 exceed indices: [0]
# 	Altitude jump of 128.875 detected at index 0
# 	 --> cut: 0.16 %
# 	 --> "V101_T294.parquet" saved.
# ------------------------------------------------------------
#
# 295/358, Reading File: V101_T41.parquet, New File Name: V101_T295
# 	 --> "V101_T295.parquet" saved.
# ------------------------------------------------------------
#
# 296/358, Reading File: V101_T42.parquet, New File Name: V101_T296
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 144.75
# 6.900000000342743e-05
# 	 exceed indices: [0]
# 	Altitude jump of 144.75 detected at index 0
# 	 --> cut: 1.54 %
# 	 --> "V101_T296.parquet" saved.
# ------------------------------------------------------------
#
# 297/358, Reading File: V101_T43.parquet, New File Name: V101_T297
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 124.125
# 5.899999996472616e-05
# 	 exceed indices: [0]
# 	Altitude jump of 124.125 detected at index 0
# 	 --> cut: 3.90 %
# 	 --> "V101_T297.parquet" saved.
# ------------------------------------------------------------
#
# 298/358, Reading File: V101_T44.parquet, New File Name: V101_T298
# 	 --> "V101_T298.parquet" saved.
# ------------------------------------------------------------
#
# 299/358, Reading File: V101_T45.parquet, New File Name: V101_T299
# 	 --> "V101_T299.parquet" saved.
# ------------------------------------------------------------
#
# 300/358, Reading File: V101_T46.parquet, New File Name: V101_T300
# 	 --> "V101_T300.parquet" saved.
# ------------------------------------------------------------
#
# 301/358, Reading File: V101_T47.parquet, New File Name: V101_T301
# 	 --> "V101_T301.parquet" saved.
# ------------------------------------------------------------
#
# 302/358, Reading File: V101_T48.parquet, New File Name: V101_T302
# 	 --> "V101_T302.parquet" saved.
# ------------------------------------------------------------
#
# 303/358, Reading File: V101_T49.parquet, New File Name: V101_T303
# 	 --> "V101_T303.parquet" saved.
# ------------------------------------------------------------
#
# 304/358, Reading File: V101_T5.parquet, New File Name: V101_T304
# 	 --> "V101_T304.parquet" saved.
# ------------------------------------------------------------
#
# 305/358, Reading File: V101_T50.parquet, New File Name: V101_T305
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T305.parquet" saved.
# ------------------------------------------------------------
#
# 306/358, Reading File: V101_T51.parquet, New File Name: V101_T306
# 	 --> "V101_T306.parquet" saved.
# ------------------------------------------------------------
#
# 307/358, Reading File: V101_T52.parquet, New File Name: V101_T307
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 129.5
# 4.100000001017179e-05
# 	 exceed indices: [0]
# 	Altitude jump of 129.5 detected at index 0
# 	 --> cut: 4.29 %
# 	 --> "V101_T307.parquet" saved.
# ------------------------------------------------------------
#
# 308/358, Reading File: V101_T53.parquet, New File Name: V101_T308
# 	 --> "V101_T308.parquet" saved.
# ------------------------------------------------------------
#
# 309/358, Reading File: V101_T54.parquet, New File Name: V101_T309
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	Signal elcomp_pwrcons_cval clipped to range (0, 14)
# 244.375
# 0.004684999999994943
# 	 exceed indices: [0]
# 	Altitude jump of 244.375 detected at index 0
# 	 --> cut: 0.03 %
# 	 --> "V101_T309.parquet" saved.
# ------------------------------------------------------------
#
# 310/358, Reading File: V101_T55.parquet, New File Name: V101_T310
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 554.75
# 0.0005219999999894753
# 	 exceed indices: [0]
# 	Altitude jump of 554.75 detected at index 0
# 	 --> cut: 0.04 %
# 	 --> "V101_T310.parquet" saved.
# ------------------------------------------------------------
#
# 311/358, Reading File: V101_T56.parquet, New File Name: V101_T311
# 	 --> "V101_T311.parquet" saved.
# ------------------------------------------------------------
#
# 312/358, Reading File: V101_T57.parquet, New File Name: V101_T312
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	Signal elcomp_pwrcons_cval clipped to range (0, 14)
# 592.5
# 0.00040000000002038405
# 	 exceed indices: [0]
# 	Altitude jump of 592.5 detected at index 0
# 	 --> cut: 0.02 %
# 	 --> "V101_T312.parquet" saved.
# ------------------------------------------------------------
#
# 313/358, Reading File: V101_T58.parquet, New File Name: V101_T313
# 	 --> "V101_T313.parquet" saved.
# ------------------------------------------------------------
#
# 314/358, Reading File: V101_T59.parquet, New File Name: V101_T314
# 	 --> "V101_T314.parquet" saved.
# ------------------------------------------------------------
#
# 315/358, Reading File: V101_T6.parquet, New File Name: V101_T315
# 	 --> "V101_T315.parquet" saved.
# ------------------------------------------------------------
#
# 316/358, Reading File: V101_T60.parquet, New File Name: V101_T316
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 222.625
# 0.0002000000000066393
# 	 exceed indices: [0]
# 	Altitude jump of 222.625 detected at index 0
# 	 --> cut: 0.45 %
# 	 --> "V101_T316.parquet" saved.
# ------------------------------------------------------------
#
# 317/358, Reading File: V101_T61.parquet, New File Name: V101_T317
# 	 --> "V101_T317.parquet" saved.
# ------------------------------------------------------------
#
# 318/358, Reading File: V101_T62.parquet, New File Name: V101_T318
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T318.parquet" saved.
# ------------------------------------------------------------
#
# 319/358, Reading File: V101_T63.parquet, New File Name: V101_T319
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 523.03125
# 0.00029299999999921056
# 	 exceed indices: [0]
# 	Altitude jump of 523.03125 detected at index 0
# 	 --> cut: 0.03 %
# 	 --> "V101_T319.parquet" saved.
# ------------------------------------------------------------
#
# 320/358, Reading File: V101_T64.parquet, New File Name: V101_T320
# 	 --> "V101_T320.parquet" saved.
# ------------------------------------------------------------
#
# 321/358, Reading File: V101_T65.parquet, New File Name: V101_T321
# 	 --> "V101_T321.parquet" saved.
# ------------------------------------------------------------
#
# 322/358, Reading File: V101_T66.parquet, New File Name: V101_T322
# 	 --> "V101_T322.parquet" saved.
# ------------------------------------------------------------
#
# 323/358, Reading File: V101_T67.parquet, New File Name: V101_T323
# 	 --> "V101_T323.parquet" saved.
# ------------------------------------------------------------
#
# 324/358, Reading File: V101_T68.parquet, New File Name: V101_T324
# 	 --> "V101_T324.parquet" saved.
# ------------------------------------------------------------
#
# 325/358, Reading File: V101_T69.parquet, New File Name: V101_T325
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T325.parquet" saved.
# ------------------------------------------------------------
#
# 326/358, Reading File: V101_T7.parquet, New File Name: V101_T326
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T326.parquet" saved.
# ------------------------------------------------------------
#
# 327/358, Reading File: V101_T70.parquet, New File Name: V101_T327
# 	Signal elcomp_pwrcons_cval clipped to range (0, 14)
# 	 --> "V101_T327.parquet" saved.
# ------------------------------------------------------------
#
# 328/358, Reading File: V101_T71.parquet, New File Name: V101_T328
# 	Signal elcomp_pwrcons_cval clipped to range (0, 14)
# 	 --> "V101_T328.parquet" saved.
# ------------------------------------------------------------
#
# 329/358, Reading File: V101_T72.parquet, New File Name: V101_T329
# 	 --> "V101_T329.parquet" saved.
# ------------------------------------------------------------
#
# 330/358, Reading File: V101_T73.parquet, New File Name: V101_T330
# 	 --> "V101_T330.parquet" saved.
# ------------------------------------------------------------
#
# 331/358, Reading File: V101_T74.parquet, New File Name: V101_T331
# 	 --> "V101_T331.parquet" saved.
# ------------------------------------------------------------
#
# 332/358, Reading File: V101_T75.parquet, New File Name: V101_T332
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T332.parquet" saved.
# ------------------------------------------------------------
#
# 333/358, Reading File: V101_T76.parquet, New File Name: V101_T333
# 	 --> "V101_T333.parquet" saved.
# ------------------------------------------------------------
#
# 334/358, Reading File: V101_T77.parquet, New File Name: V101_T334
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 	 --> "V101_T334.parquet" saved.
# ------------------------------------------------------------
#
# 335/358, Reading File: V101_T78.parquet, New File Name: V101_T335
# 	 --> "V101_T335.parquet" saved.
# ------------------------------------------------------------
#
# 336/358, Reading File: V101_T79.parquet, New File Name: V101_T336
# 	 --> "V101_T336.parquet" saved.
# ------------------------------------------------------------
#
# 337/358, Reading File: V101_T8.parquet, New File Name: V101_T337
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 188.4
# 9.757589199999991
# 	 exceed indices: [1]
# 	Altitude jump of 188.4 detected at index 1
# 	 --> cut: 0.45 %
# 	 --> "V101_T337.parquet" saved.
# ------------------------------------------------------------
#
# 338/358, Reading File: V101_T80.parquet, New File Name: V101_T338
# 	 --> "V101_T338.parquet" saved.
# ------------------------------------------------------------
#
# 339/358, Reading File: V101_T81.parquet, New File Name: V101_T339
# 	 --> "V101_T339.parquet" saved.
# ------------------------------------------------------------
#
# 340/358, Reading File: V101_T82.parquet, New File Name: V101_T340
# 	 --> "V101_T340.parquet" saved.
# ------------------------------------------------------------
#
# 341/358, Reading File: V101_T83.parquet, New File Name: V101_T341
# 	 --> "V101_T341.parquet" saved.
# ------------------------------------------------------------
#
# 342/358, Reading File: V101_T84.parquet, New File Name: V101_T342
# 	 --> "V101_T342.parquet" saved.
# ------------------------------------------------------------
#
# 343/358, Reading File: V101_T85.parquet, New File Name: V101_T343
# 	 --> "V101_T343.parquet" saved.
# ------------------------------------------------------------
#
# 344/358, Reading File: V101_T86.parquet, New File Name: V101_T344
# 	 --> "V101_T344.parquet" saved.
# ------------------------------------------------------------
#
# 345/358, Reading File: V101_T87.parquet, New File Name: V101_T345
# 	 --> "V101_T345.parquet" saved.
# ------------------------------------------------------------
#
# 346/358, Reading File: V101_T88.parquet, New File Name: V101_T346
# 	 --> "V101_T346.parquet" saved.
# ------------------------------------------------------------
#
# 347/358, Reading File: V101_T89.parquet, New File Name: V101_T347
# 	 --> "V101_T347.parquet" saved.
# ------------------------------------------------------------
#
# 348/358, Reading File: V101_T9.parquet, New File Name: V101_T348
# 112.30000000000001
# 0.0039977999999862845
# 	 exceed indices: [0]
# 	Altitude jump of 112.30000000000001 detected at index 0
# 	 --> cut: 0.25 %
# 	 --> "V101_T348.parquet" saved.
# ------------------------------------------------------------
#
# 349/358, Reading File: V101_T90.parquet, New File Name: V101_T349
# 	Signal latitude_cval_ippc clipped to range (35, 68)
# 558.75
# 4.400000000259752e-05
# 	 exceed indices: [0]
# 	Altitude jump of 558.75 detected at index 0
# 	 --> cut: 1.84 %
# 	 --> "V101_T349.parquet" saved.
# ------------------------------------------------------------
#
# 350/358, Reading File: V101_T91.parquet, New File Name: V101_T350
# 	 --> "V101_T350.parquet" saved.
# ------------------------------------------------------------
#
# 351/358, Reading File: V101_T92.parquet, New File Name: V101_T351
# 	 --> "V101_T351.parquet" saved.
# ------------------------------------------------------------
#
# 352/358, Reading File: V101_T93.parquet, New File Name: V101_T352
# 	 --> "V101_T352.parquet" saved.
# ------------------------------------------------------------
#
# 353/358, Reading File: V101_T94.parquet, New File Name: V101_T353
# 	 --> "V101_T353.parquet" saved.
# ------------------------------------------------------------
#
# 354/358, Reading File: V101_T95.parquet, New File Name: V101_T354
# 	 --> "V101_T354.parquet" saved.
# ------------------------------------------------------------
#
# 355/358, Reading File: V101_T96.parquet, New File Name: V101_T355
# 	 --> "V101_T355.parquet" saved.
# ------------------------------------------------------------
#
# 356/358, Reading File: V101_T97.parquet, New File Name: V101_T356
# Warning: All NaN values in V101_T97.parquet, columns: ['altitude_cval_ippc', 'latitude_cval_ippc', 'longitude_cval_ippc']
# ------------------------------------------------------------------------------------------------------------------------
#
# 357/358, Reading File: V101_T98.parquet, New File Name: V101_T357
# Warning: All NaN values in V101_T98.parquet, columns: ['altitude_cval_ippc', 'latitude_cval_ippc', 'longitude_cval_ippc']
# ------------------------------------------------------------------------------------------------------------------------
#
# 358/358, Reading File: V101_T99.parquet, New File Name: V101_T358
# 	 --> "V101_T358.parquet" saved.
# ------------------------------------------------------------

# %%
import pandas as pd
from pathlib import Path

# Function to check for NaN values in parquet files
def check_nan_files(folder_path):
    nan_files = []
    for file in folder_path.glob("*.parquet"):
        df = pd.read_parquet(file, engine='fastparquet')
        if df.isna().any().any():
            nan_files.append(file.name)
    return nan_files

# Define the folder paths
folders = [trips_processed_cleaned]

# Check for NaN files in each folder
for folder in folders:
    nan_files = check_nan_files(folder)
    print(f"Files with NaN values in {folder}:")
    for file in nan_files:
        print(file)
# Out:
# Files with NaN values in C:\Users\SIEGLEW\OneDrive - Daimler Truck\MA\Code\MA-Data\new_folder_2:
