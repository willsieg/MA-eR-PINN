# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/SIEGLEW/Dokumente/MA/Code/Helpers/test_data.csv')
data
# Out:
#       Voltage (V)  Current (A)  Temp (C)  Speed (km/hr)
# 0          3.8583     -0.36258    27.110              5
# 1          3.8583     -0.36258    27.110              5
# 2          3.8583     -0.36258    27.110              5
# 3          3.8583     -0.36176    27.110              5
# 4          3.8583     -0.36258    27.110              5
# ...           ...          ...       ...            ...
# 5995       3.8119     -0.66146    27.301              5
# 5996       3.8119     -0.66065    27.301              5
# 5997       3.8119     -0.66146    27.301              5
# 5998       3.8119     -0.66146    27.301              4
# 5999       3.8119     -0.66065    27.301              4
#
# [6000 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,7))

fig, axs = plt.subplots(4, 1, layout='constrained')

axs[0].plot(data['Voltage (V)'])
axs[0].set_ylabel('Voltage (V)')

axs[1].plot(data['Current (A)'])
axs[1].set_ylabel('Current (A)')

axs[2].plot(data['Temp (C)'])
axs[2].set_ylabel('Temp (C)')

axs[3].plot(data['Speed (km/hr)'])
axs[3].set_ylabel('Speed (km/hr)')

axs[-1].set_xlabel('Step')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Voltage (V)    6000 non-null   float64
#  1   Current (A)    6000 non-null   float64
#  2   Temp (C)       6000 non-null   float64
#  3   Speed (km/hr)  6000 non-null   int64
# dtypes: float64(3), int64(1)
# memory usage: 187.6 KB

# %%
import scipy.io as sio

# %%
dataLGHG = sio.loadmat(r"C:\Users\SIEGLEW\Downloads\LGHG2@n10C_to_25degC\Other_Files\TRAIN_LGHG2@25degC_Norm_5Inputs.mat")
Battery_Data = pd.DataFrame.from_dict(dataLGHG, 'index')

# %%
sio.whosmat(r"C:\Users\SIEGLEW\Downloads\LGHG2@n10C_to_25degC\Other_Files\TRAIN_LGHG2@25degC_Norm_5Inputs.mat")
# Out:
# [('X', (5, 172557), 'double'), ('Y', (1, 172557), 'double')]

# %%
Battery_Data
# Out:
#                                                              0
# __header__   b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Crea...
# __version__                                                1.0
# __globals__                                                 []
# X            [[0.29943569513289875, 0.29944764262184, 0.299...
# Y            [[0.13032666666666662, 0.13032666666666662, 0....
