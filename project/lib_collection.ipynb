# %%
# mathematical, numerical

import math
import numpy as np

# %%
# visualization

import matplotlib.pyplot as plt 
# %matplotlib inline

# example:
plt.plot(np.arange(-5,5,.1), np.tanh(np.arange(-5,5,.1))); plt.grid()
